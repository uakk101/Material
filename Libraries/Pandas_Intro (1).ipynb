# %%
# Importing Pandas
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# To check the version of the pandas on your machine
print(pd.__version__)
# Out:
# 1.5.3

# %%
mydataset = {
  'cars': ["BMW", "Toyota", "Suzuki"],
  'passings': [3, 7, 2]
}

data = pd.DataFrame(mydataset)

print(data)
# Out:
#      cars  passings
# 0     BMW         3
# 1  Toyota         7
# 2  Suzuki         2

# %% [markdown]
# # Series in Pandas
# A Pandas Series is like a column in a table.
#
# It is a one-dimensional array holding data of any type.

# %%
a = [1, 7, 2 , 10]

my_data = pd.Series(a , index = ['a' ,'b' , 'c' ,'d'])

print(my_data)
# Out:
# a     1
# b     7
# c     2
# d    10
# dtype: int64

# %% [markdown]
# # Labels
# If nothing else is specified, the values are labeled with their index number. First value has index 0, second value has index 1 etc.
# This label can be used to access a specified value.

# %%
print(my_data['a'])
# Out:
# 1

# %%
# With the index argument, you can name your own labels.
a = [1, 7, 2]

my_data_2 = pd.Series(a, index = ["x", "y", "z"])

print(my_data_2)
print(my_data_2["y"])
# Out:
# x    1
# y    7
# z    2
# dtype: int64
# 7

# %% [markdown]
# # Key/Value Objects as Series
# You can also use a key/value object, like a dictionary, when creating a Series.

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

my_data_3 = pd.Series(calories)

print(my_data_3)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
#To select only some of the items in the dictionary, use the index argument and specify only the items you want to include in the Series.
calories = {"day1": 420, "day2": 380, "day3": 390}

my_data_4 = pd.Series(calories, index = ["day1", "day3"])

print(my_data_4)
# Out:
# day1    420
# day3    390
# dtype: int64

# %% [markdown]
# # DataFrames
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
#
# Series is like a column, a DataFrame is the whole table.

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# # Locate Row
# As you can see from the result above, the DataFrame is like a table with rows and columns.
# Pandas use the loc attribute to return one or more specified row(s)

# %%
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
print(df.loc[[0, 1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %%
# naming with your own index values
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
print(df.loc["day2"])
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
# calories    380
# duration     40
# Name: day2, dtype: int64

# %% [markdown]
# # Load Files Into a DataFrame
# If your data sets are stored in a file, Pandas can load them into a DataFrame.

# %%
# Out:
#      <input type="file" id="files-da3f8fc8-984d-4629-94fb-d854930b93c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-da3f8fc8-984d-4629-94fb-d854930b93c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
